# %% [markdown]
# #  ------------------------subplot -------------------------

# %%
    import matplotlib.pyplot as plt
import numpy as np
# if using a Jupyter notebook, include:
# %matplotlib inline

t = np.arange(.01,20.0,0.2)
fig,((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2)
# linear x and y axis
ax1.plot(t,np.exp(-t/5))
ax1.set_title('linear x and y')
ax1.grid()
# linear x and logarithmic y axis
ax2.semilogy(t,np.exp(-t/5))
ax2.set_title('linear x and logarithmic y')
ax2.grid()
#logarithmic x and linear y axis
ax3.semilogx(t,np.exp(-t/5))
ax3.set_title('logarithmic x and linear y')
ax3.grid()
# log x and y axis
ax4.loglog(t, 20 * np.exp(-t / 5.0), basex=2)
ax4.set_title('loglog base 2 on x')
ax4.grid()

fig.tight_layout()
plt.show()

# %% [markdown]
# #   --------------------style----------------------

# %%
# Show the different list
for style in plt.style.available:
    print(style)

# %%
x = np.linspace(5, 20)
fig, ax = plt.subplots()

plt.style.use('dark_background')

for n in range(-20,30,10):
    ax.plot(x, np.cos(x) + np.random.randn(50) + n)
    print("*")

ax.set_title("'fivethirtyeight' style")

plt.show()

# %%
    from matplotlib import pyplot as plt  
    #ploting our canvas  
    # plt.plot([1,2,3],[1,5,1]) 
    plt.plot([1,5,1],[1,2,3]) 
    #display the graph 
    plt.title("Simple line draw using 3 point")
    plt.ylabel("Y-Axis")
    plt.xlabel("X-axis")
    plt.show()

# %%
    #Plot([y value])...x value are generated by index
    from matplotlib import pyplot as plt  
    plt.plot([1,3,3,4,5])  
    plt.ylabel("y axis")  
    plt.xlabel('x axis')  
    plt.show()

# %%
# plot([x axis value],[y axis value])
from matplotlib import pyplot as plt
plt.plot([2,2,3,4,5],[1,4,9,16,25])  
plt.ylabel("y axis")  
plt.xlabel('x axis')  
plt.show()

# %%
    # 'b' 	Using for the blue marker with default shape.
    # 'ro' 	Red circle
    # '-g' 	Green solid line
    # '--' 	A dashed line with the default color
    # '^k:' 	Black triangle up markers connected by a dotted line
    
    from matplotlib import pyplot as plt  
    plt.plot([1, 2, 3, 4,5], [1, 4, 9, 16,25], '^k:')  
    plt.axis([0, 6, 0, 20])  
    plt.show()

# %%
#subplot(number of row,number of columns , index)
# for small(three digit )

from matplotlib import pyplot as plt
names = ['Jewel', 'Mehedy', 'Asibul']  
marks= [87,50,98]  
plt.figure(figsize=(12,3)) 
# for bar graph
plt.subplot(131)  
plt.bar(names, marks)  

# for scatter plot
plt.subplot(132)  
plt.scatter(names, marks)  

# for plot
plt.subplot(133)
plt.plot(names,marks)

plt.suptitle("Categorical plotting")
plt.show()

# %% [markdown]
# # Creating different types of graph

# %%
    from matplotlib import pyplot as plt  
    from matplotlib import style  
      
    style.use('ggplot')  
    x = [16, 8, 10]  
    y = [8, 16, 6]  
    x2 = [8, 15, 11]  
    y2 = [6, 15, 7]  
    plt.plot(x, y, 'r', label='line one', linewidth=5)  
    plt.plot(x2, y2, 'm', label='line two', linewidth=5)  
    plt.title('Epic Info')  
    fig = plt.figure()  
    plt.ylabel('Y axis')  
    plt.xlabel('X axis')  
    plt.legend()  
    plt.grid(True, color='k')  
    plt.show()

# %% [markdown]
# #  ********************  NOT understands**********

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = plt.axes()
x = np.linspace(0,10,1000)
ax.plot(x,np.sin(x))


  
x = np.arange(0.0, 2, 0.01)  
y1 = np.sin(2 * np.pi * x)  
y2 = 1.2 * np.sin(4 * np.pi * x)  
fig, ax = plt.subplots(1, sharex=True)  
ax.plot(x, y1, x, y2, color='black')  
ax.fill_between(x, y1, y2, where=y2 >= y1, facecolor='blue', interpolate=True)  
ax.fill_between(x, y1, y2, where=y2 <= y1, facecolor='red', interpolate=True)  
ax.set_title('fill between where')

# %%
    # This is bar graph
    
    from matplotlib import pyplot as plt  
    players = ['Virat','Rohit','Shikhar','Hardik']  
    runs = [51,87,45,67]  
    plt.bar(players,runs,color = 'green')  
    plt.title('Score Card')  
    plt.xlabel('Players')  
    plt.ylabel('Runs')  
    plt.show()

# %%
    # just barh()  in place of bar()
    
    from matplotlib import pyplot as plt  
    players = ['Virat','Rohit','Shikhar','Hardik']  
    runs = [51,87,45,67]  
    plt.barh(players,runs, color = 'green')  
    plt.title('Score Card')  
    plt.xlabel('Runs')  
    plt.ylabel('Players')  
    plt.show()

# %%
# Style 

from matplotlib import pyplot as plt  
from matplotlib import style  
  
style.use('ggplot')  
  
x = [5,8,10]  
y = [12,16,6]  
  
x2 = [6,9,11]  
y2 = [7,15,7]  

plt.bar(x,y,color='y',align='center')
plt.bar(x2,y2,color='r',align='center')

plt.title('Information')  
plt.ylabel('Y axis')  
plt.xlabel('X axis')  

#plt.show()

# %% [markdown]
#   #               ********** problem 2  **************

# %%
    from matplotlib import pyplot as plt  
    import numpy as np  
      
    countries = ['USA', 'India', 'China', 'Russia', 'Germany']  
    bronzes = np.array([38, 17, 26, 19, 15])  
    silvers = np.array([37, 23, 18, 18, 10])  
    golds = np.array([46, 27, 26, 19, 17])  
    ind = [x for x, _ in enumerate(countries)]  
      
    plt.bar(ind, golds, width=0.5, label='golds', color='gold', bottom=silvers+bronzes)  
    plt.bar(ind, silvers, width=0.5, label='silvers', color='silver', bottom=bronzes)  
    plt.bar(ind, bronzes, width=0.5, label='bronzes', color='#CD853F')  
      
    plt.xticks(ind, countries)  
    plt.ylabel("Medals")  
    plt.xlabel("Countries")  
    plt.legend(loc="upper right")  
    plt.title("2019 Olympics Top Scorers")

# %%
Players = 'Rohit', 'Virat', 'Shikhar', 'Yuvraj'  
Runs = [45, 30, 15, 10]  
explode = (0.03, 0, 0, 0)  # it "explode" the 1st slice   
  
fig1, ax1 = plt.subplots()  
ax1.pie(Runs, explode=explode, labels=Players, autopct='%1.1f%%',  
        shadow=True, startangle=45)  
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.  
  
plt.show()

# %%
from matplotlib import pyplot as plt  
population_age = [21,53,60,49,25,27,30,42,40,1,2,102,95,8,15,105,70,65,55,70,75,60,52,44,43,42,45]  
bins = [0,20,40,60,80,100]  
plt.hist(population_age,bins,histtype = 'bar',rwidth= .8)
plt.xlabel('age groups')  
plt.ylabel('Number of people')  
plt.title('Histogram')  
plt.show()

# %%
    from matplotlib import pyplot as plt  
    # Importing Numpy Library  
    import numpy as np  
    plt.style.use('fivethirtyeight')  
      
    mu = 50  
    sigma = 7  
    x = np.random.normal(mu, sigma, size=200)  
    print(x)
#     fig, ax = plt.subplots()  
      
#     ax.hist(x, 20)  
#     ax.set_title('Historgram')  
#     ax.set_xlabel('bin range')  
#     ax.set_ylabel('frequency')  
      
#     fig.tight_layout()  
#     plt.show()

# %% [markdown]
# # Scatter plot

# %%
    import matplotlib.pyplot as plt  
    x = [2, 2.5, 3, 3.5, 4.5, 4.7, 5.0]  
    y = [7.5, 8, 8.5, 9, 9.5, 10, 10.5]  
      
    x1 = [9, 8.5, 9, 9.5,10, 10.5, 12]  
    y1 = [3, 3.5, 4.7, 4, 4.5, 5, 5.2]  
    plt.scatter(x, y, label='high income low saving', color='g')  
    plt.scatter(x1, y1, label='low income high savings', color='r')  
    plt.xlabel('saving*100')  
    plt.ylabel('income*1000')  
    plt.title('Scatter Plot')  
    plt.legend()  
    plt.show()

# %% [markdown]
# # 3D surface

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
fig = plt.figure()
ax = plt.axes(projection = '3d')
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection = '3d')
z_line = np.linspace(0,15,100)
x_line = np.cos(z_line)
y_line = np.sin(z_line)
ax.plot3D(x_line,y_line,z_line,'y')  # plt3d use for line

z_points = 15*np.random.random(100)
x_points = np.cos(z_points)+.1*np.random.random(100)
y_points = np.sin(z_points)+.1*np.random.random(100)

ax.scatter3D(x_points, y_points, z_points,c=z_points, cmap='hsv')
plt.tight_layout()
plt.show()

# %%
# plot_surface(X, Y, Z, cstride, rstride, cmap)
# plot_surface(X, Y, Z)
# plot_surface(X, Y, Z, antialiased=False, cmap, cstride, linewidth, rstride)
# plot_surface(X, Y, Z, alpha, cmap, cstride, rstride)
# plot_surface(X, Y, Z, cmap, cstride, linewidth, rstride)


# first part 
#plt.style.use()
# %matplotlib 
fig = plt.figure()
ax = plt.axes(projection="3d")

def z_function(x,y):
    return np.sin(np.sqrt(x**2+y**2))  # sin(root over(x2+y2))
x = np.linspace(-6,6,30)
y = np.linspace(-6,6,30)

X, Y = np.meshgrid(x, y)
#print(X)
Z = z_function(X, Y)

#second part
#ax.plot_wireframe(X,Y,Z,color='g')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,cmap='viridis')   # cmap = winter
ax.set_xlabel("x axis")
ax.set_ylabel("y axis")
ax.set_zlabel("z axis")
plt.show()

# %% [markdown]
# # Wireframe plots

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Grab some test data.
X, Y, Z = axes3d.get_test_data(0.05)

# Plot a basic wireframe.
ax.plot_wireframe(X, Y, Z, rstride=1, cstride=10)

plt.show()

# %% [markdown]
# # surface plot
# # %matplotlib notebook

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
#%matplotlib notebook    # use this line for zoom in/zoom-out /rotate etc

fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)  R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=.75, aspect=5)
# # rotate the axes and update
# for angle in range(0, 360):
#     ax.view_init(30, angle)
#     plt.draw()
#     plt.pause(.001)
plt.show()

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(-5, 5, 0.25)
xlen = len(X)
Y = np.arange(-5, 5, 0.25)
ylen = len(Y)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Create an empty array of strings with the same shape as the meshgrid, and
# populate it with two colors in a checkerboard pattern.
colortuple = ('y', 'b')
colors = np.empty(X.shape, dtype=str)
for y in range(ylen):
    for x in range(xlen):
        colors[x, y] = colortuple[(x + y) % len(colortuple)]

# Plot the surface with face colors taken from the array we made.
surf = ax.plot_surface(X, Y, Z, facecolors=colors, linewidth=0)

# Customize the z axis.
ax.set_zlim(-1, 1)
ax.w_zaxis.set_major_locator(LinearLocator(6))

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Make data
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, 2* np.pi, 100)
x = 10 * np.outer(np.cos(u), np.sin(v))
y = 10 * np.outer(np.sin(u), np.sin(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))

# Plot the surface
ax.plot_surface(x, y, z, color='c')

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for c, z in zip(['r', 'g', 'b', 'y'], [30, 20, 10, 0]):
    xs = np.arange(20)
    ys = np.random.rand(20)

    # You can provide either a single color or an array. To demonstrate this,
    # the first bar of each set will be colored cyan.
    cs = [c] * len(xs)
    cs[0] = 'c'
    ax.bar(xs, ys, zs=z, zdir='y', color=cs, alpha=0.8)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="852.75">
